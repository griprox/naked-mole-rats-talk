# %%
import os
import sys
path_to_this_notebook = os.path.abspath('.')
PATH_TO_PROJECT = path_to_this_notebook[: path_to_this_notebook.find('notebooks')]
sys.path.append(PATH_TO_PROJECT)

from src.metadata_processing.process_sounds_metadata import generate_sounds_metadata
from src.metadata_processing.filters import filter_sounds_metadata_extended
from src.metadata_processing.load_data import load_recordings_metadata, load_sounds
from src.audiodata_processing.process_waves import denoise_recording

from notebooks.analysis.plotting_config import ORDER, COLOR
from src.visualization.plot_softchirps import plot
from src.data_representations.process_waves import butter_highpass_filter 


import pickle
import numpy as np
import pandas as pd

from sklearn.manifold import TSNE
import umap

def compute_projection(features, projection_type, **kwargs):
    if projection_type.lower() == 'tsne':
        transform = TSNE(n_components=2, **kwargs[projection_type.lower()])
        features_projected = transform.fit_transform(features)
    
    elif projection_type.lower() == 'umap':
        transform = umap.UMAP(n_components=2, **kwargs[projection_type.lower()])
        features_projected = transform.fit_transform(features)
    elif projection_type is None:
        features_projected = features
    features_projected = pd.DataFrame(features_projected, columns=['dim#%d' % i 
                                                                   for i in range(features_projected.shape[1])])
    return features_projected
    
def choose_features(features_to_use, sounds_metadata, features, recs_dict):
    if features_to_use == 'all':
        return features
    elif features_to_use == 'mfcc':
        return features[[c for c in features.columns if 'mfcc' in c]]
    elif features_to_use == 'vae':
        raise ValueError
    else:
        return features[features_filter]
    
    
from src.data_representations.softchirp_features import *
from src.data_representations.process_wavs import *

def extract_features_sounds_metadata(sounds_metadata, recs_metadata, recs_dict=None, 
                                 sr=22050, win_length=220, n_mfcc=30, denoise=False, **denoising_params):
    features = [None for _ in range(sounds_metadata.shape[0])]
    rec_names_set = sounds_metadata['rec'].unique()
    
    for rec_numb, rec_name in enumerate(rec_names_set):
        print('Loading and processing recording %d/%d' % (rec_numb + 1, len(rec_names_set)))
        rec_path = recs_metadata[recs_metadata['name'] == rec_name]['path'].iloc[0]
        rec = recs_dict[rec_name]  
                    
        rec_sounds_inds = np.where(sounds_metadata['rec'] == rec_name)[0]
        sounds_metadata_in_rec = sounds_metadata[sounds_metadata['rec'] == rec_name]
        features_sounds_in_rec = extract_features(sounds_metadata_in_rec, rec,  sr, win_length, n_mfcc)
        for ind_loc, ind in enumerate(rec_sounds_inds):
            features[ind] = np.copy(features_sounds_in_rec.iloc[ind_loc])
        columns = features_sounds_in_rec.columns
        del(features_sounds_in_rec)
    features = pd.DataFrame(features, columns=columns)
    return features
    

def extract_features(sounds_metadata, rec, sr=22050, win_length=220, n_mfcc=30):
    features = []
    for s, e in sounds_metadata[['s', 'e']].values:
        s_int, e_int = int(sr * s), int(sr * e)
        sound = rec[s_int: e_int]
        
        pitch = compute_pitch(sound, win_length)
        ampl = compute_amplitude(sound, win_length)
        ent = compute_wiener_ent(sound, win_length)
        zero_cross = compute_zero_crossing(sound)
        duration_full = e - s
        
        mfcc_features = librosa.feature.mfcc(sound, n_mfcc=n_mfcc)
        mfcc_features = np.concatenate([mfcc_features.min(1), mfcc_features.mean(1), mfcc_features.max(1)])
        
        all_features = np.stack([pitch, ampl, ent, zero_cross, duration_full] + mfcc_features.tolist())
        features.append(all_features)
    return pd.DataFrame(features, columns=['pitch', 'amplitude', 'éntropy', 'zero crossing', 'duration'] + 
                        np.reshape([('mfcc_min%d' % i, 'mfcc_mean%d' % i, 'mfcc_max%d' % i) for i in range(30)], 
                                   (-1)).tolist())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_28502/1271292487.py in <module>
#      11
#      12 from notebooks.analysis.plotting_config import ORDER, COLOR
# ---> 13 from src.visualization.plot_softchirps import plot
#      14 from src.data_representations.process_waves import butter_highpass_filter
#      15
#
# ~/Projects/naked-mole-rats/src/visualization/plot_softchirps.py in <module>
#       7
#       8 from src.util import get_ordered_y, get_grouping_indexes
# ----> 9 from src.preprocessing_old.process_softchirp_features import choose_features
#      10 from src.visualization.plotting_utils import *
#      11
#
# ModuleNotFoundError: No module named 'src.preprocessing_old'

# %% [markdown]
# ### Parameter selection

# %%
path_to_recordings_metadata = PATH_TO_PROJECT + 'data/'
recordings_metadata_name = 'recordings_metadata.csv'

dates = 'all'
colonies = ['damkleinannotated','hvdkleinannotated','nmrkleinannotated', 
           'bsuilkleinannotated']
experiments = 'all'
stages = ['labeled and checked', 'traced and checked', 'labeled', 'traced']

sr = 22050
rec_denoising_params = {'stationary': False, 'n_fft': 512, 'time_constant_s': 0.05, 
                        'freq_mask_smooth_hz': 500, 'time_mask_smooth_ms': 10}

classes_to_drop = ['weirdo', 'badsplit']
max_sounds_per_class = {'softchirp': 99999999}
max_sound_length = 9000
min_sound_length = 1337
columns_to_copy = ['colony', 'ratids', 'date', 'experiment']

recs_dict_name = '-'.join([c[:3] for c in colonies])

# %%
if not os.path.isfile(path_to_this_notebook + '/' + recs_dict_name + '.pickle'):
    recs_metadata, recs_dict = load_recordings_metadata(path_to_recordings_metadata, 
                                                        recordings_metadata_name, 
                                                        dates, colonies, experiments, stages,)
    with open(path_to_this_notebook + '/' + recs_dict_name + '.pickle', 'wb') as f:
        pickle.dump(recs_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
else:
    print('Start loading!')
    with open(path_to_this_notebook + '/' + recs_dict_name + '.pickle', 'rb') as f:
        recs_dict = pickle.load(f, )
        print('Loaded recs dict')
    recs_metadata, recs_dict = load_recordings_metadata(path_to_recordings_metadata, 
                                                        recordings_metadata_name, 
                                                        dates, colonies, experiments, stages, 
                                                        preloaded_recs_dict=recs_dict)

if os.path.isfile(path_to_this_notebook + '/' + recs_dict_name + '_denoised' + '.pickle'):
    print('Start loading!')
    try:
        with open(path_to_this_notebook + '/' + recs_dict_name + '_denoised' + '.pickle', 'rb') as f:
            recs_dict_denoised = pickle.load(f)
            print('Loaded recs dict')
    except:
        recs_dict_denoised = {rec_name: denoise_recording(rec, sr, **rec_denoising_params)
                              for rec_name, rec in recs_dict.items()}
        with open(path_to_this_notebook + '/' + recs_dict_name + '_denoised' + '.pickle', 'wb') as f:
            pickle.dump(recs_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
else:
    recs_dict_denoised = {rec_name: denoise_recording(rec, sr, **rec_denoising_params)
                              for rec_name, rec in recs_dict.items()}
    with open(path_to_this_notebook + '/' + recs_dict_name + '_denoised' + '.pickle', 'wb') as f:
        pickle.dump(recs_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Start loading!
# Loaded recs dict
# Using 51 recordings
# Start loading!
#   0%|          | 0/238 [00:00<?, ?it/s]
#   0%|          | 0/368 [00:00<?, ?it/s]
#   0%|          | 0/411 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/83 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/133 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/17 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
#   0%|          | 0/67 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipykernel_9829/858011659.py in <module>
#      20         with open(path_to_this_notebook + '/' + recs_dict_name + '_denoised' + '.pickle', 'rb') as f:
# ---> 21             recs_dict_denoised = pickle.load(f)
#      22             print('Loaded recs dict')
#
# EOFError: Ran out of input
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_9829/858011659.py in <module>
#      25                               for rec_name, rec in recs_dict.items()}
#      26         with open(path_to_this_notebook + '/' + recs_dict_name + '_denoised' + '.pickle', 'wb') as f:
# ---> 27             pickle.dump(recs_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
#      28 else:
#      29     recs_dict_denoised = {rec_name: denoise_recording(rec, sr, **rec_denoising_params)
#
# MemoryError:

# %%
sounds_metadata = generate_sounds_metadata(recs_metadata, classes_to_drop, max_sounds_per_class,
                                               min_sound_length, max_sound_length, columns_to_copy,
                                               sr, print_counts=False)
# Out:
# /home/nakedmoleratvoices/src/preprocessing/process_sounds_metadata.py:35: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   sounds_metadata = pd.concat(sounds_metadata, 0).reset_index(drop=True)

# %%
features = extract_features_sounds_metadata(sounds_metadata, recs_metadata, recs_dict, 
                                            sr=22050, win_length=220, n_mfcc=30)

features_denoised = extract_features_sounds_metadata(sounds_metadata, recs_metadata, recs_dict_denoised, 
                                                     sr=22050, win_length=220, n_mfcc=30)
sounds_npy = load_sounds(sounds_metadata, recs_dict, timestamps='sec')
sounds_npy_denoised = load_sounds(sounds_metadata, recs_dict_denoised, timestamps='sec')
# Out:
# Loading and processing recording 1/49
# Loading and processing recording 2/49
# Loading and processing recording 3/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=2024
#   n_fft, y.shape[-1]
# Loading and processing recording 4/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=2029
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1765
#   n_fft, y.shape[-1]
# Loading and processing recording 5/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1766
#   n_fft, y.shape[-1]
# Loading and processing recording 6/49
# Loading and processing recording 7/49
# Loading and processing recording 8/49
# Loading and processing recording 9/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1852
#   n_fft, y.shape[-1]
# Loading and processing recording 10/49
# Loading and processing recording 11/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1764
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1676
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1763
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1674
#   n_fft, y.shape[-1]
# Loading and processing recording 12/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1941
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=2030
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1589
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1943
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1938
#   n_fft, y.shape[-1]
# Loading and processing recording 13/49
# Loading and processing recording 14/49
# Loading and processing recording 15/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=2027
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1588
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1851
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1680
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1496
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1944
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1502
#   n_fft, y.shape[-1]
# Loading and processing recording 16/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=2028
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1411
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1853
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1675
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1500
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1497
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1416
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1760
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1761
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1937
#   n_fft, y.shape[-1]
# Loading and processing recording 17/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=2031
#   n_fft, y.shape[-1]
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1677
#   n_fft, y.shape[-1]
# Loading and processing recording 18/49
# Loading and processing recording 19/49
# Loading and processing recording 20/49
# Loading and processing recording 21/49
# Loading and processing recording 22/49
# Loading and processing recording 23/49
# Loading and processing recording 24/49
# Loading and processing recording 25/49
# Loading and processing recording 26/49
# Loading and processing recording 27/49
# Loading and processing recording 28/49
# Loading and processing recording 29/49
# Loading and processing recording 30/49
# Loading and processing recording 31/49
# Loading and processing recording 32/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1413
#   n_fft, y.shape[-1]
# Loading and processing recording 33/49
# Loading and processing recording 34/49
# Loading and processing recording 35/49
# Loading and processing recording 36/49
# Loading and processing recording 37/49
# Loading and processing recording 38/49
# Loading and processing recording 39/49
# Loading and processing recording 40/49
# Loading and processing recording 41/49
# Loading and processing recording 42/49
# Loading and processing recording 43/49
# Loading and processing recording 44/49
# Loading and processing recording 45/49
# Loading and processing recording 46/49
# Loading and processing recording 47/49
# /opt/conda/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1767
#   n_fft, y.shape[-1]
# Loading and processing recording 48/49
# Loading and processing recording 49/49
# Loading and processing recording 1/49
# Loading and processing recording 2/49
# Loading and processing recording 3/49
# Loading and processing recording 4/49
# Loading and processing recording 5/49
# Loading and processing recording 6/49
# Loading and processing recording 7/49
# Loading and processing recording 8/49
# Loading and processing recording 9/49
# Loading and processing recording 10/49
# Loading and processing recording 11/49
# Loading and processing recording 12/49
# Loading and processing recording 13/49
# Loading and processing recording 14/49
# Loading and processing recording 15/49
# Loading and processing recording 16/49
# Loading and processing recording 17/49
# Loading and processing recording 18/49
# Loading and processing recording 19/49
# Loading and processing recording 20/49
# Loading and processing recording 21/49
# Loading and processing recording 22/49
# Loading and processing recording 23/49
# Loading and processing recording 24/49
# Loading and processing recording 25/49
# Loading and processing recording 26/49
# Loading and processing recording 27/49
# Loading and processing recording 28/49
# Loading and processing recording 29/49
# Loading and processing recording 30/49
# Loading and processing recording 31/49
# Loading and processing recording 32/49
# Loading and processing recording 33/49
# Loading and processing recording 34/49
# Loading and processing recording 35/49
# Loading and processing recording 36/49
# Loading and processing recording 37/49
# Loading and processing recording 38/49
# Loading and processing recording 39/49
# Loading and processing recording 40/49
# Loading and processing recording 41/49
# Loading and processing recording 42/49
# Loading and processing recording 43/49
# Loading and processing recording 44/49
# Loading and processing recording 45/49
# Loading and processing recording 46/49
# Loading and processing recording 47/49
# Loading and processing recording 48/49
# Loading and processing recording 49/49

# %%
list(sounds_metadata['rec'].unique())
# Out:
# ['hvdkleinannotated_02-09-19_0000002.npy',
#  'hvdkleinannotated_02-09-19_0000003.npy',
#  'hvdkleinannotated_02-09-19_0000001.npy',
#  'damkleinannotated_13-10-21_0000149.npy',
#  'damkleinannotated_13-10-21_0000151.npy',
#  'damkleinannotated_13-10-21_0000150.npy',
#  'damkleinannotated_13-10-21_0000153.npy',
#  'damkleinannotated_13-10-21_0000154.npy',
#  'damkleinannotated_13-10-21_0000148.npy',
#  'damkleinannotated_13-10-21_0000152.npy',
#  'damkleinannotated_13-10-21_0000147.npy',
#  'nmrkleinannotated_08-10-21_0000123.npy',
#  'nmrkleinannotated_08-10-21_0000121.npy',
#  'nmrkleinannotated_08-10-21_0000122.npy',
#  'nmrkleinannotated_08-10-21_0000118.npy',
#  'nmrkleinannotated_08-10-21_0000117.npy',
#  'nmrkleinannotated_08-10-21_0000119.npy',
#  'nmrkleinannotated_08-10-21_0000120.npy',
#  'nmrkleinannotated_08-10-21_0000124.npy',
#  'bsuilkleinannotated_26-11-21_20000043.npy',
#  'bsuilkleinannotated_26-11-21_20000033.npy',
#  'bsuilkleinannotated_26-11-21_10000046.npy',
#  'bsuilkleinannotated_26-11-21_10000041.npy',
#  'bsuilkleinannotated_26-11-21_10000035.npy',
#  'bsuilkleinannotated_26-11-21_10000031.npy',
#  'bsuilkleinannotated_26-11-21_20000032.npy',
#  'bsuilkleinannotated_26-11-21_10000037.npy',
#  'bsuilkleinannotated_26-11-21_10000039.npy',
#  'bsuilkleinannotated_26-11-21_10000043.npy',
#  'bsuilkleinannotated_26-11-21_20000044.npy',
#  'bsuilkleinannotated_26-11-21_20000046.npy',
#  'bsuilkleinannotated_26-11-21_10000033.npy',
#  'bsuilkleinannotated_26-11-21_20000034.npy',
#  'bsuilkleinannotated_26-11-21_20000039.npy',
#  'bsuilkleinannotated_26-11-21_10000040.npy',
#  'bsuilkleinannotated_26-11-21_10000045.npy',
#  'bsuilkleinannotated_26-11-21_20000037.npy',
#  'bsuilkleinannotated_26-11-21_20000038.npy',
#  'bsuilkleinannotated_26-11-21_10000034.npy',
#  'bsuilkleinannotated_26-11-21_20000042.npy',
#  'bsuilkleinannotated_26-11-21_20000031.npy',
#  'bsuilkleinannotated_26-11-21_20000041.npy',
#  'bsuilkleinannotated_26-11-21_10000036.npy',
#  'bsuilkleinannotated_26-11-21_10000042.npy',
#  'bsuilkleinannotated_26-11-21_10000038.npy',
#  'bsuilkleinannotated_26-11-21_20000035.npy',
#  'bsuilkleinannotated_26-11-21_10000032.npy',
#  'bsuilkleinannotated_26-11-21_20000045.npy',
#  'bsuilkleinannotated_26-11-21_20000040.npy']

# %%
# Set filters
use_denoising = True

colonies = 'all'
colonies = [
            #'hvdkleinannotated', 
            #'damkleinannotated', 
            #'bsuilkleinannotated',
            'nmrkleinannotated'
            ]
weights = 'all'
dates = 'all'
sexes = 'all' 
ages = 'all'
ranks = 'all' 
ratids = 'all'
excludeids = None 
bodylengths = 'all'
bodylengths2 = 'all' 
sounds_per_rat = [0, np.inf]
max_sounds_per_colony = 10000
types = 'all'
#rec_names = ['damkleinannotated_13-10-21_0000150.npy']
rec_names = 'all'

classes_to_plot = 'all'
classes_to_drop = ['sound', 'sc', 'softchirp']

mask =  filter_sounds_metadata_extended(sounds_metadata, ratids, excludeids, 
                                   types, colonies, weights, sexes, ages, ranks, dates,
                                   bodylengths, bodylengths2, sounds_per_rat)
if classes_to_plot != 'all':
    mask *= sounds_metadata['cl'].isin(classes_to_plot)
if classes_to_drop:
    mask *= ~sounds_metadata['cl'].isin(classes_to_drop)
if rec_names != 'all' and rec_names is not None:
    mask *= sounds_metadata['rec'].isin(rec_names)
    
mask_select = np.ones(len(sounds_metadata), dtype = 'bool')
id_inds = {}
for col in set(sounds_metadata['colony'][mask]):
    col_inds = np.where((sounds_metadata['colony'] == col) & mask)[0]
    if len(col_inds) > max_sounds_per_colony:
        np.random.shuffle(id_inds)
        mask_select[col_inds[max_sounds_per_colony:]] = False
        mask_select[col_inds[max_sounds_per_colony:]] = False
mask *= mask_select
    
sounds_metadata_filtered = sounds_metadata[mask].reset_index(drop=True)
if use_denoising:
    features_filtered = features_denoised[mask].reset_index(drop=True)
    sounds_npy_filtered = [sounds_npy_denoised[i] for i in np.where(mask)[0]]
else:
    features_filtered = features[mask].reset_index(drop=True)
    sounds_npy_filtered = [sounds_npy[i] for i in np.where(mask)[0]]
recs_dict = recs_dict_denoised if use_denoising else recs_dict
print(sounds_metadata_filtered['colony'].value_counts())
# Out:
# nmrkleinannotated    2321
# Name: colony, dtype: int64

# %%
features_to_use = 'all' # 'mfcc', 'wave', list of 'pitch', 'duration' etc., 'vae'

features_final = choose_features(features_to_use, 
                                 sounds_metadata_filtered, 
                                 features_filtered,
                                 recs_dict)

# %%
projection_type = 'tsne'
all_projections_kwargs = {'pca': {'kernel': 'linear'}, 
                          'tsne': {'perplexity': 10.0}, 
                          'umap': {'min_dist': .1, 'metric': 'euclidean', 'n_neighbors': 40} 
                         }
features_final_projected = compute_projection(features_final, projection_type, **all_projections_kwargs)

# %%
color_by = 'cl'
y_raw = sounds_metadata_filtered[color_by]
y_unique = sorted(set(y_raw))
y = pd.Series([y_unique.index(yi) for yi in y_raw], name=y_raw.name)

group_by_rat = False
plot_color_mean = False
group_color_column = False
plot_ellipses = False

order = ORDER[color_by]
order = None
color_dict = COLOR[color_by]
color_dict = None

plot(features_final_projected, y_raw, sounds_metadata_filtered, 'all', None, group_by_rat, group_color_column, 
     plot_ellipses, plot_color_mean, color_dict, order, sizes_factor=32)

# %%
from src.deep_learning.vae import VAE
import torch
from torch.utils.data import DataLoader
from src.deep_learning.util import *


spec_params = {'num_freq_bins': 128,
               'num_time_bins': 128,
               'nperseg': 512, 
               'noverlap': 256, 
               'min_freq': 2000,
               'max_freq': 11025,
               'spec_min_val': -10, 
               'spec_max_val': 0,
               'remove_dc_offset': True, 
               'mel': False, 
               'max_dur': 0.4, 
               'time_stretch': True}


specs = extract_specs_vae(sounds_metadata, sounds_npy, spec_params, sr=22050, fill_value=-1/9999,)
data = [torch.from_numpy(S, ).float() for S in specs]
dl = DataLoader(data, batch_size=128, shuffle=True, sampler=None,)
model = VAE(save_dir='.', lr=5e-4, z_dim=32, model_precision=10.0, device_name="auto")

for epoch in range(1, 541):
    print('Epoch', epoch)
    loss = model.train_epoch(dl)
    #if epoch % 20 == 0:
    #    model.save_state(model_folder + '/model')

# %%
def sound_to_spec_vae(sound, p, sr=22050,  fill_value=-1/EPSILON, ):
    
    if p['remove_dc_offset']:
        sound = sound - np.mean(sound)

    f, t, spec = stft(sound, fs=sr, nperseg=p['nperseg'], noverlap=p['noverlap'])
    t *= sr
    spec = np.log(np.abs(spec) + EPSILON)
    spec_pre_interp = np.copy(spec)
    interp = interp2d(t, f, spec_pre_interp, copy=False, bounds_error=False, fill_value=fill_value)

    target_freqs = None
    target_times = None

    if p['mel']: 
        target_freqs = np.linspace(_mel(p['min_freq']), _mel(p['max_freq']), p['num_freq_bins'])
        target_freqs = _inv_mel(target_freqs)
    else:
        target_freqs = np.linspace(p['min_freq'], p['max_freq'], p['num_freq_bins'])
        
    max_dur_int = p['max_dur'] * sr
    duration = len(sound)
    t1, t2 = 0, duration
    if p['time_stretch']:
        duration = np.sqrt(duration * max_dur_int) # stretched duration
    shoulder = 0.5 * (max_dur_int - duration)
    target_times = np.linspace(t1-shoulder, t2+shoulder, p['num_time_bins'])

    # Then interpolate.
    spec = interp(target_times, target_freqs, assume_sorted=True)
    # Normalize.
    spec -= p['spec_min_val']
    spec /= (p['spec_max_val'] - p['spec_min_val'])
    spec = np.clip(spec, 0.0, 1.0)
    
    return spec

def extract_specs_vae(sounds_metadata, sounds, p, sr=22050, fill_value=-1/EPSILON,):
    specs_new = []
    for (s, e, rec_name), sound in zip(sounds_metadata[['s', 'e', 'rec']].values, sounds):
        spec = sound_to_spec_vae(sound, p, sr=sr,  fill_value=fill_value )
        specs_new.append(np.flip(spec, 0))
    return np.array(specs_new)
