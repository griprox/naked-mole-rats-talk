# %%
import os
import sys
path_to_this_notebook = os.path.abspath('.')
PATH_TO_PROJECT = path_to_this_notebook[: path_to_this_notebook.find('notebooks')]
sys.path.append(PATH_TO_PROJECT)
from src.metadata_processing.load_data import *
from src.metadata_processing.process_softchirp_features import find_outliers, choose_features
from src.audiodata_processing.extract_features_from_softchirps import compute_all_features
from src.audiodata_processing.process_traces import clear_trace
from src.metadata_processing.filters import filter_recs_metadata, filter_sounds_metadata_extended
from src.metadata_processing.process_sounds_metadata import extend_sounds_metadata, compute_epochs
from src.visualization.plot_softchirps import plot
from src.util import delete_indexes
import src.visualization.plot_softchirps
from notebooks.analysis.plotting_config import ORDER, COLOR, EPOCHS # change plotting_config file to change colors

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from collections import defaultdict
import matplotlib
import matplotlib.cm as cm
# %matplotlib inline

# %% [markdown]
# ### Parameter selection

# %%
# specify paths, where data is stored
path_to_info = PATH_TO_PROJECT + 'data/rat_info.csv'
path_to_recordings_metadata = PATH_TO_PROJECT + 'data/'
recordings_metadata_name = 'recordings_metadata.csv'

# what data to load, set filters here
colonies = ['baratheon','dothrakib', 'martell', 'targaryen']
#colonies = 'all'
dates = 'all'
experiments = ['single rat softchirps']
stages = ['traced and checked',]

# specifies seconds to pixels ratio for spectrogram image
# uses librosa library which downsamples all audio files to 22050
freq_mult = 22050 / 2  / 128

# specify outliers,soft chirp traces outside of these ranges are excluded from analysis  
boundaries = {'slope' : (0.01, .2), 
              'frequency' : (2000, 8000), 
              'duration' : (0.05, 10),
              'height' : (300, 6000)}

# %% [markdown]
# ### Load data

# %%
# load info- and meta- data
info = load_info_file(path_to_info)
recs_metadata = pd.read_csv(path_to_recordings_metadata + recordings_metadata_name, dtype={'ratids': str})

# filter what will be used (this is specified above)
mask = filter_recs_metadata(recs_metadata, dates, colonies, stages, experiments)
recs_to_analyse = recs_metadata[mask]

# load recording wavs, sound wavs and traces, create sounds metadata (master file)
recs_dict = load_recs_dict(recs_to_analyse)
traces, wavs, sounds_metadata = load_traces_wavs_and_metadata(recs_to_analyse, info, recs_dict)
sounds_metadata_extended = extend_sounds_metadata(sounds_metadata, info)
traces = [clear_trace(t, ) for t in traces]

# compute softchirp features
features, inds_skipped = compute_all_features(traces, wavs, freq_mult)
traces, wavs, sounds_metadata_extended = delete_indexes(inds_skipped, traces, wavs, sounds_metadata_extended)

# compute epochs 
sounds_metadata_extended = compute_epochs(sounds_metadata_extended, EPOCHS)

# remove outliers
outliers = find_outliers(features, boundaries )
features, sounds_metadata_extended = delete_indexes(outliers, features, sounds_metadata_extended)
print('Features could not be extracted from %d traces' % len(inds_skipped))
print('%d traces were deleted as outliers' %  len(outliers))
print('%d traces are left' % (len(sounds_metadata_extended)))
# Out:
# /home/gr1/Projects/naked-mole-rats/src/metadata_processing/process_sounds_metadata.py:109: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   return pd.concat([sounds_metadata.reset_index(drop = True), columns_to_add], 1)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-5.75526412e-05 -1.01124870e-02 -9.02801963e-03 ... -6.02382458e-04
#   3.73620591e-03  1.81092228e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-8.81521510e-06  4.89195816e-03 -9.76785051e-03 ... -1.21693453e-02
#   5.27200784e-03 -1.82083559e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 8.48002357e-05  7.03521721e-03  1.07983997e-02 ...  1.70189558e-03
#   1.09149794e-03 -6.65912156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 6.24074249e-06 -1.98497266e-03  4.18805899e-04 ... -1.04055046e-04
#  -5.77695523e-03  4.94539037e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 7.42250329e-05 -4.54441142e-03  7.69065433e-03 ... -1.52045228e-02
#  -7.76204046e-03 -2.26580301e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.15087558e-05  1.79873148e-03  9.73148338e-03 ...  5.88406499e-03
#  -6.86908665e-04 -5.33638138e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.09752678e-05 -4.89091311e-03 -3.31709240e-03 ...  4.86883557e-02
#   2.19025564e-02  4.41052926e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-7.98815432e-05 -2.94472931e-04  1.97772732e-03 ... -2.65465122e-03
#  -1.40523043e-03 -7.22982671e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-8.22650538e-05  5.36602049e-03 -6.44965032e-03 ...  8.64676301e-03
#   1.36407672e-03  2.55110740e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-0.00033602 -0.00366723 -0.01309598 ... -0.02018351 -0.01022575
#  -0.00020449] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.54828773e-06 -1.99802079e-04  3.03205253e-03 ...  5.84389061e-03
#   1.12887711e-02 -5.94761218e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.73493010e-05 -2.13465142e-04 -2.08546082e-03 ...  9.79355408e-03
#   6.88937707e-03  6.61580045e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-0.00035152 -0.05235747 -0.02943268 ...  0.00353499  0.01159197
#   0.00011401] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 4.42799771e-05  1.10719060e-03 -3.64099267e-04 ... -2.01368439e-03
#   7.52108469e-04 -2.94126724e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.99796754e-05  2.90850513e-03 -4.98938713e-03 ...  2.29303992e-03
#   1.35546415e-02  5.50764747e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 8.38293313e-05  4.60062584e-03  1.49326193e-02 ...  1.13095367e-03
#  -1.31508274e-02 -8.81789357e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.58470802e-05 -2.30276329e-03 -3.80906487e-03 ...  2.46622490e-03
#  -1.48363224e-03  7.97016759e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.06168543e-05  6.21016114e-04 -7.75492908e-04 ... -4.37627216e-03
#  -7.50535656e-04 -8.75074817e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.76300520e-05  1.01609350e-03 -1.29814410e-02 ... -1.16813107e-02
#   9.24893626e-03 -1.13112049e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 8.71463859e-05  1.28908001e-02  4.38356937e-03 ... -2.78162919e-03
#   7.13455053e-05 -1.96557272e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.42676883e-05 -4.80656787e-03  1.11696710e-03 ...  1.99457245e-02
#  -1.93137479e-03  1.17730023e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 6.25671886e-05  2.72936878e-03  2.60768137e-03 ... -2.68204038e-04
#  -4.42628777e-03 -2.50690585e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.27258302e-05 -5.01385818e-03 -4.81615869e-03 ... -6.64498824e-04
#   4.72061234e-03 -6.49562749e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.59628332e-06 -4.34014048e-03 -2.22978907e-03 ... -7.54909260e-03
#  -1.66016420e-03  6.90998746e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.31649258e-05 -4.27436530e-03 -3.02345021e-04 ...  2.99576209e-03
#  -1.23828950e-03  4.32686863e-06] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.35475710e-05 -2.33676426e-04 -7.65140307e-04 ... -3.08443204e-03
#   9.76234601e-03 -1.30078133e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 4.92415386e-06  2.20648076e-03  1.71575751e-03 ...  9.45189767e-04
#   1.61905067e-03 -1.89415915e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-6.36231615e-05  3.85170237e-04  5.84068006e-03 ...  4.90534496e-03
#  -7.75909540e-03  5.10643776e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 4.62823722e-06 -3.18138139e-03 -2.10751884e-03 ... -4.25378619e-03
#  -9.36128434e-03 -3.45283692e-06] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.90272824e-05  1.95544985e-04  1.51949196e-03 ... -1.40083694e-03
#  -1.28369206e-03 -2.41328087e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 6.72631610e-05 -2.51104155e-03 -1.65180327e-03 ... -1.61790137e-02
#  -2.05862078e-02 -2.92294863e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.04476517e-05 -4.47626906e-03  8.64738160e-03 ... -2.66931025e-02
#  -6.96902611e-03  4.75863753e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.37669481e-06 -5.10975994e-03  3.21436656e-03 ...  2.11921771e-02
#  -1.93912229e-03  5.55337802e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00135192 -0.14799223 -0.11324964 ...  0.01788005  0.00719967
#   0.00032732] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.96030603e-05  3.95732395e-03  1.62224134e-03 ... -1.58588168e-02
#   1.62296231e-03 -5.85977085e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.72829017e-06  4.63113229e-03 -1.01417727e-03 ...  1.52246807e-02
#   3.37544869e-03  2.27447272e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.29440239e-05 -2.58581405e-02 -2.31431444e-02 ... -4.97858424e-03
#  -6.25540866e-03  2.11543720e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-0.00010574  0.04122373  0.03925797 ... -0.01703099 -0.02538775
#   0.00038046] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.20589347e-04  3.34739178e-02  5.46262304e-02 ... -1.06614647e-02
#  -9.05037984e-03 -3.82038180e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-6.77521377e-05  7.96793120e-03  4.76866277e-04 ...  1.90247081e-02
#   2.37057079e-02 -1.70067767e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.44185762e-06 -2.56912255e-02 -5.20394758e-03 ...  1.91137754e-02
#  -1.52291215e-02  1.19539304e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.08408505e-04 -6.36806414e-02 -3.28844645e-02 ... -2.04568920e-02
#   2.99235094e-03 -1.71876061e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.15151300e-04 -1.38617171e-02 -1.77581421e-02 ...  4.60011090e-03
#   5.42142071e-03 -2.27116651e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 8.50011873e-06  1.21749671e-03  3.62601463e-03 ... -3.23829986e-03
#  -1.92161999e-03  1.09486524e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.84459340e-05 -1.14589270e-03  9.04736293e-04 ... -4.76978294e-04
#   4.69831275e-03  5.85358579e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.11674982e-05 -1.27506888e-03 -2.87549907e-03 ...  1.39664645e-03
#  -5.40952515e-04 -5.35933503e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.93174164e-05 -2.19680673e-04 -1.61128517e-03 ... -9.87796991e-04
#  -2.34425209e-03 -4.39388332e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-2.71596705e-06  5.52605590e-03  7.92061041e-03 ... -4.67139911e-03
#  -3.64502413e-05  7.73817548e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.18974581e-05 -1.35383755e-03  7.73960895e-04 ...  2.64616609e-03
#   1.39805413e-03  5.79831440e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.93098814e-05  1.63042597e-03 -1.16031800e-03 ... -3.36447226e-03
#  -4.71171167e-03 -3.87350245e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.06512136e-05 -2.44284161e-03 -1.84250955e-03 ...  3.35944157e-04
#  -6.85390099e-04  7.69059402e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.06590277e-06 -1.78427594e-04  4.01353964e-04 ...  3.12674437e-03
#   2.65338156e-03  1.10038735e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-8.86425294e-06 -7.65836685e-04  6.90372909e-04 ...  5.87142491e-04
#   1.21533474e-03  4.51281044e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.99853372e-05 -2.47622963e-03  1.44253938e-03 ...  9.03361472e-04
#   2.74418571e-03  6.63784353e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-7.87263955e-06  3.48363116e-04 -5.44875859e-04 ... -8.82575987e-03
#  -8.24289275e-03  1.40722640e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-2.52702378e-05 -2.37215608e-03  1.93664703e-04 ...  2.26018958e-03
#  -2.03675243e-04  4.99044190e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-6.13214571e-05 -5.99461952e-04 -6.75363621e-04 ... -2.54527671e-03
#  -4.97633687e-03 -1.23266566e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.05950991e-05 -1.06715642e-03 -2.48476560e-03 ... -1.50769038e-03
#   7.50291919e-04  8.41451886e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.96046384e-05  1.81132741e-04 -4.18633029e-03 ... -7.95490873e-04
#   2.17233341e-03 -2.21081479e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-6.58465755e-06  1.71077847e-03  1.87316404e-03 ... -4.56690828e-03
#  -6.01993853e-03  3.06676576e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.15101904e-05 -2.69682191e-03 -1.48627496e-03 ... -2.78134299e-05
#   2.51358116e-03  4.71725836e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-2.46529021e-05 -1.59417555e-03  1.83273618e-03 ... -1.54269430e-03
#  -1.86457796e-03 -9.76063070e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.39078403e-05 -4.50484469e-03 -3.48189051e-03 ...  2.54338605e-04
#  -3.60760016e-03 -2.52003348e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.02386969e-05 -2.65470425e-03 -1.84036785e-03 ...  2.74797546e-04
#  -5.66823517e-04  4.70467384e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.54115607e-05  1.22873147e-03  7.44765561e-04 ... -5.26107201e-05
#  -2.60090670e-03 -4.71266216e-06] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.70946966e-05 -2.17816576e-03  1.90136836e-04 ... -1.83960110e-04
#   3.39734762e-03  3.62391534e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.71991455e-05 -1.27288589e-03 -1.78154793e-03 ... -1.20836838e-03
#  -2.83478494e-04  3.20502711e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.31498596e-05 -8.42564817e-04 -4.18882155e-04 ...  1.69354200e-03
#  -1.57364815e-03 -3.12486052e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-2.05923856e-04  5.01387626e-04 -7.12525377e-03 ... -6.24660235e-03
#   2.42877927e-03 -8.73083594e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-8.45325298e-05 -4.55308010e-03 -1.79459195e-03 ...  7.48273530e-03
#   1.22664223e-02 -6.34856661e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.11675053e-05 -1.81596384e-03 -3.29734816e-03 ...  4.40048168e-03
#   5.16512385e-03  3.21134478e-07] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.98059649e-06  1.18433143e-03  1.34691228e-03 ...  2.40041720e-03
#   2.94016162e-03 -6.44450437e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-2.37456503e-06 -8.67264918e-04 -1.11738464e-03 ... -2.81848472e-03
#  -1.01911691e-02 -1.14506951e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.84131976e-05 -1.57369084e-03 -1.89751058e-03 ... -1.81890661e-04
#  -3.67601066e-03  3.60281949e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 7.41726889e-05  2.67413394e-03 -8.09921291e-03 ... -5.13106323e-03
#  -2.23277434e-03 -1.46656169e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.08650767e-04 -1.13241511e-02 -1.41542741e-02 ...  1.11763578e-02
#   1.48755495e-02  6.66030161e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 4.60139511e-05 -4.88310357e-04  4.39617759e-03 ...  7.02324965e-03
#   7.72740780e-03 -2.99780978e-06] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 6.98149102e-05 -1.99600385e-04  2.52088769e-03 ... -3.34445136e-03
#   6.58871507e-03 -1.13456932e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 9.44790136e-05  1.49782003e-02 -1.15188106e-02 ...  5.41070755e-04
#  -2.24989297e-03  2.38879403e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00015043 -0.01353464 -0.00564284 ... -0.01046978  0.03392661
#   0.00025239] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 7.75841056e-05  4.45456081e-03  3.40128293e-03 ... -2.39313647e-03
#  -3.46797065e-03  1.11214486e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00013879 -0.00716529 -0.01041589 ... -0.00531358 -0.00926971
#   0.0001866 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.63227047e-05 -4.50892755e-03 -6.21193746e-03 ... -7.91147426e-04
#   1.59631507e-02 -3.63012414e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.84378326e-05  2.79763514e-03 -5.59436376e-03 ...  2.24842679e-03
#   1.10388661e-03 -1.43924712e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-5.52647785e-05  8.80038006e-03  6.97653587e-03 ... -5.05484630e-03
#  -8.42255973e-03 -1.91292605e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 9.68095285e-05  1.16755663e-02 -3.86066752e-03 ... -2.36322265e-03
#   3.00664204e-03 -1.10331233e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.47314393e-04 -1.26165015e-05  9.25419347e-05 ...  1.92121370e-03
#   1.12769767e-02  2.62161664e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-0.00016389  0.01171589  0.00782509 ...  0.00397457 -0.02262943
#   0.00014897] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.56403584e-06 -2.23200029e-03 -1.81174127e-03 ...  8.41694224e-03
#   7.56128404e-03 -1.85373960e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.75385953e-06  2.65926207e-03  3.37604932e-03 ...  4.89553072e-03
#  -2.01235616e-03 -5.07760932e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.73342885e-05 -9.13579176e-03  7.08803724e-03 ... -8.85841072e-04
#   9.87716558e-03 -5.86090833e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-2.46628046e-06  1.02538593e-02 -7.66849391e-03 ...  1.04993952e-02
#  -4.61532225e-03 -9.97579138e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 6.11662176e-05 -8.59487085e-03 -6.29014144e-03 ... -9.43773390e-03
#  -7.85131641e-03  3.60065507e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.10791738e-05 -7.68529930e-03 -9.42427909e-04 ...  4.03991199e-03
#   1.05498648e-02 -1.50877210e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-5.50277571e-05  2.41028601e-03  6.71122424e-03 ...  8.38664435e-03
#  -2.55356648e-03  1.70782607e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.73149990e-05  6.76118968e-03 -3.11637899e-03 ...  4.79246648e-03
#   1.99486640e-03  2.90695396e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.06418843e-05  1.13164133e-02  1.00805151e-02 ... -7.15457227e-03
#  -4.63811818e-03  3.40974530e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.05182524e-05 -2.84500902e-02 -2.44241176e-02 ... -1.02760579e-02
#  -9.43502725e-03  1.13805563e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.72570766e-05  1.17977485e-02  2.95036756e-03 ...  3.92017375e-03
#   1.05822664e-02 -2.51775932e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00095676 -0.05586822 -0.0506696  ...  0.02389033  0.00754047
#  -0.00053445] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 4.57490062e-05 -1.78769082e-02 -1.88652616e-03 ...  8.37322239e-03
#  -6.90299239e-04  4.95354467e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-0.00027039 -0.16380386  0.07986539 ...  0.01032807  0.01418892
#   0.00019876] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 7.58513769e-05  1.02377047e-04  9.60490672e-04 ... -7.44655949e-03
#   5.96679471e-04  1.28719263e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-7.85027955e-05  7.26210204e-03  5.56016793e-03 ... -2.88454189e-05
#  -1.42882379e-02  1.10964706e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.60516031e-05  2.98740498e-03  9.84401163e-03 ...  1.13875466e-03
#   1.98315371e-03 -1.22264058e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00043763 -0.02132662 -0.04613361 ...  0.01123101  0.00011203
#   0.0001562 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-5.30853483e-05 -7.73661845e-03 -5.63820622e-03 ...  1.99795670e-02
#   1.45638388e-02 -2.02764788e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.34245015e-04  3.10082772e-03  1.63142898e-04 ...  3.60755257e-03
#   9.07082185e-03  2.41714399e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.98548709e-04 -1.18252920e-02 -1.56216825e-02 ... -5.47273258e-04
#   1.22307211e-02  7.54077146e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.94655173e-05 -1.84586261e-03 -7.13268327e-03 ...  1.13678721e-03
#  -1.54952522e-02 -6.33730003e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.69524767e-05  5.83814169e-03  3.84325639e-03 ... -2.55403702e-03
#   4.03505149e-03 -1.86703030e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.52139684e-05 -2.57849135e-05  2.73346023e-03 ...  2.71433603e-03
#  -1.31708483e-03  4.95366830e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 6.54703538e-05 -6.06052417e-03 -8.09632205e-03 ... -7.34360456e-06
#   3.54094060e-04  5.31006317e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.98281248e-05  4.17171726e-04 -1.83820067e-03 ...  1.24142865e-04
# ...
#   3.71358152e-03  1.07460030e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-5.11927948e-05  1.60531350e-03 -1.98457499e-03 ... -2.14144409e-02
#  -1.52696428e-02 -5.89194653e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.54057892e-05  1.93805999e-02  9.40030226e-03 ...  7.65366038e-03
#   4.93767964e-03  1.20587664e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-7.74974381e-05 -3.44268223e-04  2.89132856e-03 ... -2.03618704e-02
#  -1.77045974e-02 -3.37275714e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-1.04183055e-04 -2.67533474e-03 -7.13956451e-03 ... -2.88840594e-03
#   6.07678761e-03 -8.96060198e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00034771  0.05619475  0.01050074 ... -0.00240981  0.00624567
#  -0.00050529] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.46780888e-05  7.88840144e-03  1.17890675e-03 ... -1.29239291e-02
#  -3.11753841e-02 -9.63254409e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00043855 -0.02600019 -0.01482613 ... -0.01668    -0.0194455
#  -0.00020464] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 0.00020293 -0.00067251 -0.00191162 ...  0.1211307   0.0917956
#  -0.00071071] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.23782617e-05 -7.94905302e-03 -3.94085456e-04 ...  6.89810737e-03
#  -9.86163218e-04 -2.70737721e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.45532400e-05 -5.93223202e-04 -3.67962402e-03 ...  5.14608410e-03
#  -4.84706244e-03  1.16127750e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.84315688e-05 -3.33331559e-03 -2.25915729e-03 ...  2.98572037e-03
#   1.62496817e-03 -2.40229611e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 9.06640279e-05 -7.90577702e-03 -1.32073493e-02 ...  1.76000331e-02
#   2.89116963e-02 -3.47266831e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 6.55950577e-05 -1.17932832e-02 -1.88740229e-03 ...  5.60605703e-03
#  -2.86419758e-03  1.68764676e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.98120706e-05 -1.11455216e-02 -8.77116455e-03 ...  6.64307067e-03
#  -1.70399987e-03 -1.36824250e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-6.92524862e-05  1.03777951e-02  1.33012420e-02 ...  1.19832722e-02
#   1.04373926e-02 -1.87396123e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.21831345e-04  1.41852124e-02 -2.24080566e-02 ...  1.59617490e-04
#   9.02387567e-03  8.65857908e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-3.87314773e-05  8.62932672e-03  7.08046185e-03 ... -3.01143174e-03
#   1.78901073e-03  4.45386748e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 4.55559773e-05  1.73982508e-03 -4.22664399e-03 ...  1.07620944e-02
#  -3.96236009e-03 -4.48076253e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-7.08875053e-05  7.63295066e-03  1.11177536e-02 ... -2.13238841e-03
#  -1.72116034e-02 -6.49147562e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 7.46257212e-05 -1.96407889e-03  8.40002576e-04 ... -8.51218605e-03
#  -6.95142269e-03 -5.06177347e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# Features could not be extracted from 0 traces
# 26 traces were deleted as outliers
# 3337 traces are left
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.46885799e-05  9.91194477e-03  1.46338078e-02 ... -5.38778434e-03
#  -2.01350436e-03  1.28856015e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-2.58830489e-05  3.43520152e-04  3.02743405e-03 ...  4.32514523e-03
#  -9.35886195e-05  7.07045668e-06] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.46913940e-05  5.67596292e-03  4.59393430e-03 ... -3.72312035e-03
#  -2.32551274e-03  2.24996471e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-0.00020773  0.01549714  0.00177795 ...  0.00444684  0.00218361
#  -0.00015232] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.58864934e-05 -1.09151837e-03 -9.49771208e-03 ... -6.02390089e-04
#   6.37972192e-04 -1.38461681e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.06668825e-05  4.84896961e-03  3.87835927e-03 ... -1.16372434e-02
#  -9.84793389e-03 -1.33600842e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.88211382e-06 -6.13455506e-03 -3.27296147e-05 ...  4.52666929e-03
#  -5.57316224e-03  1.07613676e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.68034544e-05  1.27212396e-02  1.54905174e-02 ...  8.58128435e-03
#   1.69616447e-02 -4.69796499e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-6.58891687e-05  1.63942403e-03 -7.90292538e-03 ... -3.70443676e-03
#  -4.31643678e-03 -3.51953600e-06] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-4.98265184e-05 -7.26603064e-03 -3.98485846e-03 ... -1.02112720e-02
#  -7.28529206e-03  7.71972247e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.91261476e-05 -1.67645985e-03 -3.03365107e-03 ...  1.48689205e-02
#   6.75680455e-03 -1.18913653e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 1.92570351e-06 -1.21303450e-03 -6.08468230e-03 ... -4.41914203e-03
#  -7.97713153e-03 -5.41151028e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 5.61137069e-05 -5.09409490e-03 -1.51480346e-03 ...  2.21066118e-02
#  -6.46839959e-03  1.72986859e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-0.00010004 -0.00826458 -0.01226271 ...  0.0102816   0.01196648
#   0.00014662] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 2.56196727e-05  6.52553781e-03 -1.02321074e-03 ...  1.72287304e-02
#   2.08748571e-02 -8.66421540e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[ 3.14100971e-05 -1.96107023e-03 -1.19092023e-02 ...  8.57614036e-04
#   6.37943220e-03  1.78867853e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)
# /home/gr1/Projects/naked-mole-rats/src/audiodata_processing/extract_features_from_softchirps.py:57: FutureWarning: Pass y=[-9.85150619e-06  3.79281310e-03 -2.53572253e-03 ...  9.73402439e-03
#   2.69533756e-03  5.38948373e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   pitches, magnitudes = piptrack(s_npy, sr = 22050, fmin= 2000, fmax=8000, win_length = win_length)

# %%
save_excel = False
#save_path  = '' 
# creates master list of data as an excel file
all_data_table = pd.concat([sounds_metadata_extended, features], 1)
# save
if save_excel:
    all_data_table.to_excel('all_data!.xlsx')
all_data_table.head()
# Out:
# /home/gr1/miniconda3/envs/nmr/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   after removing the cwd from sys.path.
#                                    rec     colony      date ratids  \
# 0  targaryen_21-06-19_1540_0000001.npy  targaryen  21-06-19   1540
# 1  targaryen_21-06-19_1540_0000001.npy  targaryen  21-06-19   1540
# 2  targaryen_21-06-19_1540_0000001.npy  targaryen  21-06-19   1540
# 3  targaryen_21-06-19_1540_0000001.npy  targaryen  21-06-19   1540
# 4  targaryen_21-06-19_1540_0000001.npy  targaryen  21-06-19   1540
#
#               experiment          s          e         cl  weight sex  ...  \
# 0  single rat softchirps  11.274240  11.478186  softchirp    62.7   M  ...
# 1  single rat softchirps  79.824807  80.017052  softchirp    62.7   M  ...
# 2  single rat softchirps  76.481134  76.729297  softchirp    62.7   M  ...
# 3  single rat softchirps  12.203401  12.452698  softchirp    62.7   M  ...
# 4  single rat softchirps  68.219320  68.368390  softchirp    62.7   M  ...
#
#   epoch     slope    frequency        pitch  amplitude wiener_entropy  \
# 0     ?  0.039790  4210.460880  7527.238969   0.157745       0.434090
# 1     ?  0.050981  4553.113841  7554.853103   0.214237       0.154787
# 2     ?  0.037342  4346.350331  6187.929443   0.141614       0.571743
# 3     ?  0.037632  4388.968790  7748.259803   0.189999       0.248410
# 4     ?  0.051858  3900.094145  3881.810254   0.098010       0.152116
#
#    zero_crossings  duration       height   asymmetry
# 0        0.419613  0.154848  1981.054688 -602.929688
# 1        0.385940  0.154550  1894.921875  -86.132812
# 2        0.386879  0.174490  2239.453125 -344.531250
# 3        0.411133  0.175287  2153.320312 -430.664062
# 4        0.358077  0.118492  1550.390625 -344.531250
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Plotting

# %%
# specify what is plotted
print('Keys: ', list(sounds_metadata_extended.columns))
# specify filters
colonies = ['baratheon','dothrakib', 'martell', 'targaryen']
weights = 'all'
dates = 'all'
sexes = 'all' # options: 'M', 'F', or 'all'
ages = 'all' # set range: (0, np.inf)
ranks = 'all' 
ratids =  'all'
excludeids = None # options: '1111', or None
bodylengths = 'all'# or set range
bodylengths2 = 'all' # or set range
sounds_per_rat = [0, 10000]
types = 'all'# options for types: 'single', 'pairs', or 'all'

# how to plot
color_by = 'colony' #specfies color option in graph
#options = 'colony', 'age', 'weight'
features_to_plot = ['frequency', 'asymmetry']
#features_to_plot = 'pca' #can make PCA ot tSNE plots of all features
perplexity = 50 #only required for tSNE

group_by_rat = True # plots mean values for each animal
plot_color_mean = True # plots mean for color_by grouping (i.e. colony)
group_color_column = None
plot_ellipses = True # plots ellipses representing 95% confidence intervals


order = ORDER[color_by]
color_dict = COLOR[color_by]


mask =  filter_sounds_metadata_extended(sounds_metadata_extended, ratids, excludeids, 
                                   types, colonies, weights, sexes, ages, ranks, dates,
                                   bodylengths, bodylengths2, sounds_per_rat)
features_masked = features[mask]
sounds_metadata_masked = sounds_metadata_extended[mask]
y = sounds_metadata_masked[color_by]


plot(features_masked, y, sounds_metadata_masked, features_to_plot, perplexity,
     group_by_rat, group_color_column, plot_ellipses, plot_color_mean,
     color_dict, order, sizes_factor = 32)
# Out:
# Keys:  ['rec', 'colony', 'date', 'ratids', 'experiment', 's', 'e', 'cl', 'weight', 'sex', 'rank', 'dob', 'age', 'bodylength', 'bodylength2', 'epoch']
# /home/gr1/Projects/naked-mole-rats/src/util.py:37: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(indexes)
