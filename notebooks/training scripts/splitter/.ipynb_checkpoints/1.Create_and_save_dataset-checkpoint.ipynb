# %%
import os
import sys
path_to_this_notebook = os.path.abspath('.')
PATH_TO_PROJECT = path_to_this_notebook[: path_to_this_notebook.find('notebooks')]
sys.path.append(PATH_TO_PROJECT)

import numpy as np
import pandas as pd
import os
import pickle
import matplotlib.pyplot as plt

from src.deep_learning.splitter_datasets import create_data_for_splitter

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
path_to_recordings_metadata = PATH_TO_PROJECT + 'data/'
recordings_metadata_name = 'recordings_metadata.csv'

# what data to load
dates = 'all'
colonies = 'all'
experiments = 'all'
stages = ['traced and checked', 'labeled and checked', 'split and checked']
sr = 22050

use_rec_denoising = False
rec_denoising_params = {'stationary': False, 'n_fft': 512, 'time_constant_s': 0.05, 
                        'freq_mask_smooth_hz': 500, 'time_mask_smooth_ms': 10}

classes_to_drop = ['weirdo', 'badsplit']
max_sounds_per_class = {'softchirp': 20000}
max_sound_length = 9000
min_sound_length = 1337
train_ratio = 0.92
columns_to_copy = ['colony', 'ratids', 'date', 'experiment']

resolution = 2048
step = 1024
frequency_threshold = 3000

n_fft = 512
n_mel = 80
use_melspecs = True
wave_augment_params = {'augment': False, 
                       'times_each_sound': 2, 
                       'stretching_lims': None,
                       'add_noise_lims': (0.001, 0.005), }

# %%
all_params_dict = {'sr': sr,
                   'recs_metadata': 
                   {'dates': dates, 'colonies': colonies, 'experiments': experiments, 'stages': stages,
                    'path_to_recordings_metadata': path_to_recordings_metadata, 
                    'recordings_metadata_name': recordings_metadata_name},
                  'rec_denoising':
                   {'use_rec_denoising': use_rec_denoising, 'rec_denoising_params': rec_denoising_params},
                   'sounds_metadata':
                   {'classes_to_drop': classes_to_drop, 'max_sounds_per_class': max_sounds_per_class, 
                    'max_sound_length': max_sound_length, 'min_sound_length': min_sound_length, 
                    'train_ratio': train_ratio, 'columns_to_copy': columns_to_copy},
                  'features': {'resolution':resolution, 'step': step, 'frequency_threshold': frequency_threshold,
                               'n_fft': n_fft, 'n_mel': n_mel, 'wave_augment_params': wave_augment_params, 
                               'use_melspecs': use_melspecs}}

# %%
path_to_save = PATH_TO_PROJECT + 'models/splitter/deep_splitter/datasets/'
dataset_name = 'res=%d_step%d_nfft=%d_nmel=%d_rec-denoise=%s_highpass=%s' % (resolution, step, n_fft, 
                                                                             n_mel, use_rec_denoising, 
                                                                             frequency_threshold)

# %%
recs_metadata, recs_dict = load_recordings_metadata(path_to_recordings_metadata, recordings_metadata_name,
                                           dates, colonies, experiments, stages)
if use_rec_denoising:
    recs_dict = {rec_name: denoise_recording(rec, sr, **rec_denoising_params) 
                 for rec_name, rec in recs_dict.items()}
recs_metadata.head()
# Out:
# Using 1056 recordings
#       colony      date             experiment  \
# 0  targaryen  21-06-19  single rat softchirps
# 1      stark  21-06-19  single rat softchirps
# 2  targaryen  08-11-19  single rat softchirps
# 3      arryn  24-05-19  single rat softchirps
# 4  targaryen  08-11-19  single rat softchirps
#
#                                   name  number  \
# 0  targaryen_21-06-19_1540_0000001.npy     1.0
# 1      stark_21-06-19_1545_0000001.npy     1.0
# 2  targaryen_08-11-19_1538_0000085.npy    85.0
# 3      arryn_24-05-19_9624_0000001.npy     1.0
# 4  targaryen_08-11-19_4030_0000097.npy    97.0
#
#                                                 path     processing stage  \
# 0  /home/nakedmoleratvoices/data/targaryen/record...   traced and checked
# 1    /home/nakedmoleratvoices/data/stark/recordings/  labeled and checked
# 2  /home/nakedmoleratvoices/data/targaryen/record...   traced and checked
# 3    /home/nakedmoleratvoices/data/arryn/recordings/   traced and checked
# 4  /home/nakedmoleratvoices/data/targaryen/record...   traced and checked
#
#   ratids
# 0   1540
# 1   1545
# 2   1538
# 3   9624
# 4   4030

# %%
path_to_save = PATH_TO_PROJECT + 'models/splitter/deep_splitter/datasets/'

for resolution in [1024, 2048]:
    step = int(resolution / 2)
    all_params_dict['features']['resolution'] = resolution
    all_params_dict['features']['step'] = step
    
    dataset_name = 'res=%d_step%d_nfft=%d_nmel=%d_rec-denoise=%s_highpass=%s' % (resolution, step, n_fft, 
                                                                             n_mel, use_rec_denoising, 
                                                                             frequency_threshold)
    (sounds_metadata_train, sounds_npy_train, melspecs_train,
     sounds_metadata_test,  sounds_npy_test, 
     melspecs_test) =  create_data_for_splitter(all_params_dict, dataset_name,  path_to_save, save=True,
                                                preloaded_recs_dict=recs_dict)
        
        
        
resolution = 2048
step = 1024
all_params_dict['features']['resolution'] = resolution
all_params_dict['features']['step'] = step

for n_fft in [512, 1024]:
    for n_mel in [40, 80]:
        all_params_dict['features']['n_fft'] = n_fft
        all_params_dict['features']['n_mel'] = n_mel
        dataset_name = 'res=%d_step%d_nfft=%d_nmel=%d_rec-denoise=%s_highpass=%s' % (resolution, step, n_fft, 
                                                                             n_mel, use_rec_denoising, 
                                                                             frequency_threshold)
        (sounds_metadata_train, sounds_npy_train, melspecs_train,
         sounds_metadata_test,  sounds_npy_test, 
         melspecs_test) =  create_data_for_splitter(all_params_dict, dataset_name,  path_to_save, save=True,
                                                    preloaded_recs_dict=recs_dict)
# Out:
# Using 1056 recordings
# /home/nakedmoleratvoices/src/preprocessing/process_sounds_metadata.py:35: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   sounds_metadata = pd.concat(sounds_metadata, 0).reset_index(drop=True)
# Using 918 recordings (44387 sounds)for train and  80 recordings (3521 sounds)for test
#
# ############ Classes in train:############
#
# noise              23128
# softchirp          18436
# downsweep            707
# pupcombo             535
# whistle              332
# combotwo             229
# combo                211
# grunt                156
# pupcheveron          153
# loudchirp            115
# upsweep              104
# scream                91
# pupsquawk             76
# phee                  27
# hiccup                20
# RFIDscanner           18
# mordent               18
# vtrill                13
# tweet                 12
# invertedmordent        6
# Name: cl, dtype: int64
# ############ Classes in test: ############
#
# noise          1942
# softchirp      1378
# pupcombo         71
# downsweep        39
# combo            16
# combotwo         16
# pupcheveron      15
# grunt            14
# pupsquawk        10
# upsweep           9
# whistle           4
# loudchirp         3
# hiccup            3
# phee              1
# Name: cl, dtype: int64
# Saved !!!
# Using 1056 recordings
# Using 918 recordings (45491 sounds)for train and  80 recordings (2422 sounds)for test
#
# ############ Classes in train:############
#
# noise              23853
# softchirp          18809
# downsweep            712
# pupcombo             546
# whistle              323
# combotwo             237
# combo                226
# grunt                166
# pupcheveron          138
# loudchirp            117
# upsweep              108
# pupsquawk             77
# scream                70
# phee                  25
# hiccup                21
# mordent               18
# RFIDscanner           16
# vtrill                13
# tweet                 10
# invertedmordent        6
# Name: cl, dtype: int64
# ############ Classes in test: ############
#
# noise          1217
# softchirp      1010
# pupcombo         60
# downsweep        34
# pupcheveron      30
# scream           21
# whistle          13
# pupsquawk         9
# combotwo          8
# upsweep           5
# grunt             4
# phee              3
# RFIDscanner       2
# hiccup            2
# tweet             2
# combo             1
# loudchirp         1
# Name: cl, dtype: int64
# Saved !!!
# Using 1056 recordings
# Using 920 recordings (42446 sounds)for train and  80 recordings (5448 sounds)for test
#
# ############ Classes in train:############
#
# noise              21868
# softchirp          17857
# downsweep            670
# pupcombo             564
# whistle              252
# combotwo             243
# combo                213
# pupcheveron          154
# grunt                146
# upsweep              107
# loudchirp             91
# scream                91
# pupsquawk             75
# phee                  26
# hiccup                22
# RFIDscanner           18
# mordent               18
# vtrill                13
# tweet                 12
# invertedmordent        6
# Name: cl, dtype: int64
# ############ Classes in test: ############
#
# noise          3202
# softchirp      1943
# whistle          84
# downsweep        76
# pupcombo         42
# loudchirp        27
# grunt            24
# combo            14
# pupcheveron      14
# pupsquawk        11
# upsweep           6
# combotwo          2
# phee              2
# hiccup            1
# Name: cl, dtype: int64
# Saved !!!
# Using 1056 recordings
# Using 915 recordings (44903 sounds)for train and  80 recordings (3003 sounds)for test
#
# ############ Classes in train:############
#
# noise              23968
# softchirp          18197
# downsweep            681
# pupcombo             550
# whistle              325
# combotwo             211
# combo                208
# pupcheveron          160
# grunt                153
# loudchirp            109
# upsweep              105
# pupsquawk             76
# scream                44
# phee                  27
# hiccup                22
# mordent               18
# RFIDscanner           18
# vtrill                13
# tweet                 12
# invertedmordent        6
# Name: cl, dtype: int64
# ############ Classes in test: ############
#
# softchirp      1615
# noise          1102
# downsweep        65
# pupcombo         56
# scream           47
# combotwo         34
# combo            19
# grunt            17
# whistle          11
# pupsquawk        10
# loudchirp         9
# upsweep           8
# pupcheveron       8
# phee              1
# hiccup            1
# Name: cl, dtype: int64
# Saved !!!
# Using 1056 recordings
# Using 920 recordings (44008 sounds)for train and  80 recordings (3890 sounds)for test
#
# ############ Classes in train:############
#
# noise              23215
# softchirp          18116
# downsweep            668
# pupcombo             564
# combotwo             233
# whistle              231
# combo                193
# pupcheveron          154
# grunt                151
# upsweep              103
# scream                91
# loudchirp             88
# pupsquawk             86
# phee                  28
# hiccup                21
# RFIDscanner           18
# mordent               18
# vtrill                13
# tweet                 11
# invertedmordent        6
# Name: cl, dtype: int64
# ############ Classes in test: ############
#
# noise          1855
# softchirp      1688
# whistle         105
# downsweep        78
# pupcombo         42
# combo            34
# loudchirp        30
# grunt            19
# pupcheveron      14
# combotwo         12
# upsweep          10
# hiccup            2
# tweet             1
# Name: cl, dtype: int64
# Saved !!!
# Using 1056 recordings
# Using 913 recordings (42726 sounds)for train and  80 recordings (5160 sounds)for test
#
# ############ Classes in train:############
#
# noise              22946
# softchirp          17259
# downsweep            594
# pupcombo             559
# whistle              259
# combo                209
# pupcheveron          164
# combotwo             159
# grunt                142
# upsweep              113
# loudchirp             92
# pupsquawk             78
# scream                44
# phee                  24
# hiccup                20
# mordent               17
# RFIDscanner           16
# vtrill                13
# tweet                 12
# invertedmordent        6
# Name: cl, dtype: int64
# ############ Classes in test: ############
#
# softchirp      2533
# noise          2124
# downsweep       152
# combotwo         86
# whistle          77
# scream           47
# pupcombo         47
# grunt            28
# loudchirp        26
# combo            18
# pupsquawk         8
# phee              4
# pupcheveron       4
# hiccup            3
# RFIDscanner       2
# mordent           1
# Name: cl, dtype: int64
# Saved !!!

# %%
  df_txt = create_txt(rec_labels, th, min_length=min_length, sr=sr)
    df_txt = broaden_timestamps(df_txt, rec, each_side=broaden_factor, sr=sr)

    rec_labels = np.zeros(len(rec), dtype='int')
    for s, e, cl in df_txt.values:
        if cl == 'sound':
            s_rec, e_rec = int(sr * s), int(sr * e)
            rec_labels[s_rec: e_rec] = 1

    img_labels = []
    for ind in np.arange(0, len(rec) - px_to_smp, px_to_smp):
        pixel_label = np.mean(rec_labels[int(ind): int(ind + px_to_smp)])
        img_labels.append(pixel_label)
    img_labels = np.array(img_labels)
